# %% [markdown]
# <a href="https://colab.research.google.com/github/tabowsy/NTU-MACHINE-LEARNING-2021-SPRING/blob/main/HW6_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat May  1 09:11:53 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
workspace_dir = './gdrive/MyDrive/HW6'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # ref styleGAN
# https://github.com/lucidrains/stylegan2-pytorch

# %%
pip install stylegan2_pytorch
# Out:
# Collecting stylegan2_pytorch
#   Downloading https://files.pythonhosted.org/packages/9a/ea/33e16a288f5e9962fa5f7243a79762665a75334c62a87a496ddebd99ed6c/stylegan2_pytorch-1.8.1-py3-none-any.whl
# Collecting kornia
#   Downloading https://files.pythonhosted.org/packages/0e/34/ae98eca1eee195a93e466100b451b0c962b22746e702f66f40099f798ed5/kornia-0.5.1-py2.py3-none-any.whl (275kB)
#      |████████████████████████████████| 276kB 11.7MB/s
# Collecting retry
#   Downloading https://files.pythonhosted.org/packages/4b/0d/53aea75710af4528a25ed6837d71d117602b01946b307a3912cb3cfcbcba/retry-0.9.2-py2.py3-none-any.whl
# Collecting einops
#   Downloading https://files.pythonhosted.org/packages/5d/a0/9935e030634bf60ecd572c775f64ace82ceddf2f504a5fd3902438f07090/einops-0.3.0-py2.py3-none-any.whl
# Collecting fire
#   Downloading https://files.pythonhosted.org/packages/11/07/a119a1aa04d37bc819940d95ed7e135a7dcca1c098123a3764a6dcace9e7/fire-0.4.0.tar.gz (87kB)
#      |████████████████████████████████| 92kB 7.2MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stylegan2_pytorch) (4.41.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from stylegan2_pytorch) (0.9.1+cu101)
# Collecting vector-quantize-pytorch>=0.1.0
#   Downloading https://files.pythonhosted.org/packages/a2/7b/afcdb6c49019a288e8f085f6edf5cf86f15fc176ddf0e0b4dffb66fa1dd5/vector_quantize_pytorch-0.1.0.tar.gz
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from stylegan2_pytorch) (7.1.2)
# Collecting contrastive-learner>=0.1.0
#   Downloading https://files.pythonhosted.org/packages/7e/19/a3d1b4f9c19758c8000dd13b40789791f06bb9bd9922d7e28c4b2a3b41cb/contrastive_learner-0.1.1-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from stylegan2_pytorch) (1.8.1+cu101)
# Collecting aim
#   Downloading https://files.pythonhosted.org/packages/23/b1/33ee1d060640d2ae27ee79ccead0d5f45ded36250bca5c1c6860c841ac91/aim-2.3.0-py2.py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 12.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stylegan2_pytorch) (1.19.5)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /usr/local/lib/python3.7/dist-packages (from retry->stylegan2_pytorch) (1.10.0)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.7/dist-packages (from retry->stylegan2_pytorch) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire->stylegan2_pytorch) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire->stylegan2_pytorch) (1.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->stylegan2_pytorch) (3.7.4.3)
# Collecting anytree>=2.8.0
#   Downloading https://files.pythonhosted.org/packages/a8/65/be23d8c3ecd68d40541d49812cd94ed0f3ee37eb88669ca15df0e43daed1/anytree-2.8.0-py2.py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 7.5MB/s
# Collecting GitPython>=3.0.4
#   Downloading https://files.pythonhosted.org/packages/a6/99/98019716955ba243657daedd1de8f3a88ca1f5b75057c38e959db22fb87b/GitPython-3.1.14-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 15.5MB/s
# Requirement already satisfied: click>=6.7 in /usr/local/lib/python3.7/dist-packages (from aim->stylegan2_pytorch) (7.1.2)
# Collecting docker>=4.1.0
#   Downloading https://files.pythonhosted.org/packages/b2/5a/f988909dfed18c1ac42ad8d9e611e6c5657e270aa6eb68559985dbb69c13/docker-5.0.0-py2.py3-none-any.whl (146kB)
#      |████████████████████████████████| 153kB 15.5MB/s
# Collecting aimrecords==0.0.7
#   Downloading https://files.pythonhosted.org/packages/53/13/207ebb5b2315640a68378c31cb31cfe1182373d11a813bd52219c83700a7/aimrecords-0.0.7-py2.py3-none-any.whl
# Collecting psutil>=5.6.7
#   Downloading https://files.pythonhosted.org/packages/84/da/f7efdcf012b51506938553dbe302aecc22f3f43abd5cffa8320e8e0588d5/psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl (296kB)
#      |████████████████████████████████| 296kB 19.7MB/s
# Requirement already satisfied: protobuf>=3.11.0 in /usr/local/lib/python3.7/dist-packages (from aim->stylegan2_pytorch) (3.12.4)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from aim->stylegan2_pytorch) (2.23.0)
# Collecting py3nvml>=0.2.5
#   Downloading https://files.pythonhosted.org/packages/53/b3/cb30dd8cc1198ae3fdb5a320ca7986d7ca76e23d16415067eafebff8685f/py3nvml-0.2.6-py3-none-any.whl (55kB)
#      |████████████████████████████████| 61kB 8.8MB/s
# Collecting pyrser>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/b2/c1/172359000c21c146aadf887f4d788a9fa95f7fcf466a52634add2933fcf3/pyrser-0.2.0-py2.py3-none-any.whl (70kB)
#      |████████████████████████████████| 71kB 8.7MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/ea/e8/f414d1a4f0bbc668ed441f74f44c116d9816833a48bf81d22b697090dba8/gitdb-4.0.7-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 8.5MB/s
# Collecting websocket-client>=0.32.0
#   Downloading https://files.pythonhosted.org/packages/08/33/80e0d4f60e84a1ddd9a03f340be1065a2a363c47ce65c4bd3bae65ce9631/websocket_client-0.58.0-py2.py3-none-any.whl (61kB)
#      |████████████████████████████████| 61kB 8.0MB/s
# Collecting base58==2.0.1
#   Downloading https://files.pythonhosted.org/packages/3c/03/58572025c77b9e6027155b272a1b96298e711cd4f95c24967f7137ab0c4b/base58-2.0.1-py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.11.0->aim->stylegan2_pytorch) (56.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->aim->stylegan2_pytorch) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->aim->stylegan2_pytorch) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->aim->stylegan2_pytorch) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->aim->stylegan2_pytorch) (2.10)
# Collecting xmltodict
#   Downloading https://files.pythonhosted.org/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl
# Collecting smmap<5,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/68/ee/d540eb5e5996eb81c26ceffac6ee49041d473bc5125f2aa995cf51ec1cf1/smmap-4.0.0-py2.py3-none-any.whl
# Building wheels for collected packages: fire, vector-quantize-pytorch
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=74b60c6dcae57fa214bacf46213900e7cc38c157b393683f1f1df8a53a408175
#   Stored in directory: /root/.cache/pip/wheels/af/19/30/1ea0cad502dcb4e66ed5a690279628c827aea38bbbab75d5ed
#   Building wheel for vector-quantize-pytorch (setup.py) ... done
#   Created wheel for vector-quantize-pytorch: filename=vector_quantize_pytorch-0.1.0-cp37-none-any.whl size=2576 sha256=a43111eaec1438664c96b89b9544db116044177ab54d598006ec8a56d9169ecb
#   Stored in directory: /root/.cache/pip/wheels/10/68/a9/2eb0d1f485a2babf71ac5e471c9d45703cf2a2cc8686f780d2
# Successfully built fire vector-quantize-pytorch
# Installing collected packages: kornia, retry, einops, fire, vector-quantize-pytorch, contrastive-learner, anytree, smmap, gitdb, GitPython, websocket-client, docker, base58, aimrecords, psutil, xmltodict, py3nvml, pyrser, aim, stylegan2-pytorch
#   Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed GitPython-3.1.14 aim-2.3.0 aimrecords-0.0.7 anytree-2.8.0 base58-2.0.1 contrastive-learner-0.1.1 docker-5.0.0 einops-0.3.0 fire-0.4.0 gitdb-4.0.7 kornia-0.5.1 psutil-5.8.0 py3nvml-0.2.6 pyrser-0.2.0 retry-0.9.2 smmap-4.0.0 stylegan2-pytorch-1.8.1 vector-quantize-pytorch-0.1.0 websocket-client-0.58.0 xmltodict-0.12.0

# %% [markdown]
# # train

# %%
# !stylegan2_pytorch --data "{workspace_dir}/faces" --name "faces" --results_dir "{workspace_dir}/result" --models_dir "{workspace_dir}/model" --image-size 64 --num-workers 8
# Out:
# continuing from previous epoch - 149
# loading from version 1.8.1
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# faces<./gdrive/MyDrive/HW6/faces>:  99% 149000/150000 [00:00<?, ?it/s]G: 1.89 | D: 0.80 | GP: 0.03
# faces<./gdrive/MyDrive/HW6/faces>:  99% 149047/150000 [00:53<19:06,  1.20s/it]G: 0.74 | D: 0.58 | GP: 0.28 | PL: 0.82
# faces<./gdrive/MyDrive/HW6/faces>:  99% 149089/150000 [01:53<21:18,  1.40s/it]G: 0.72 | D: 0.54 | GP: 0.15 | PL: 0.82
# faces<./gdrive/MyDrive/HW6/faces>:  99% 149143/150000 [02:55<17:34,  1.23s/it]G: 1.66 | D: 0.75 | GP: 0.10 | PL: 0.82
# faces<./gdrive/MyDrive/HW6/faces>:  99% 149196/150000 [04:12<19:10,  1.43s/it]G: 0.73 | D: 0.66 | GP: 0.14 | PL: 0.82
# faces<./gdrive/MyDrive/HW6/faces>:  99% 149245/150000 [05:12<16:14,  1.29s/it]G: 0.44 | D: 0.57 | GP: 0.08 | PL: 0.82
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149292/150000 [06:30<16:38,  1.41s/it]G: 0.66 | D: 0.66 | GP: 0.38 | PL: 0.82
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149342/150000 [07:40<13:43,  1.25s/it]G: 0.99 | D: 0.68 | GP: 1.04 | PL: 0.82
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149392/150000 [08:31<13:40,  1.35s/it]G: 0.58 | D: 0.69 | GP: 0.13 | PL: 0.82
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149441/150000 [09:41<13:54,  1.49s/it]G: 0.62 | D: 0.66 | GP: 0.18 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149496/150000 [10:47<10:59,  1.31s/it]G: 0.78 | D: 0.74 | GP: 0.13 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149548/150000 [11:57<09:51,  1.31s/it]G: -0.10 | D: 0.83 | GP: 0.12 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149591/150000 [13:00<08:11,  1.20s/it]G: 0.45 | D: 0.70 | GP: 0.08 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149644/150000 [14:04<08:25,  1.42s/it]G: 0.78 | D: 0.76 | GP: 0.27 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149697/150000 [15:16<07:15,  1.44s/it]G: 0.36 | D: 0.72 | GP: 0.40 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149747/150000 [16:20<05:36,  1.33s/it]G: 0.82 | D: 0.95 | GP: 1.33 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149793/150000 [17:29<05:18,  1.54s/it]G: 0.61 | D: 0.53 | GP: 0.02 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149846/150000 [18:41<03:51,  1.50s/it]G: 0.98 | D: 0.84 | GP: 0.35 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149897/150000 [19:50<02:29,  1.45s/it]G: 0.68 | D: 0.74 | GP: 0.14 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 149948/150000 [20:50<01:04,  1.24s/it]G: 0.88 | D: 1.08 | GP: 0.22 | PL: 0.81
# faces<./gdrive/MyDrive/HW6/faces>: 100% 150000/150000 [22:02<00:00, 113.43it/s]

# %% [markdown]
# # generator

# %%
for i in range(334):
  print(i)
  # !stylegan2_pytorch  --data "{workspace_dir}/faces" --name "faces" --results_dir "{workspace_dir}/output" --models_dir "{workspace_dir}/model" --image-size 64 --num-image-tiles 1 --generate
# Out:
# 0
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.51it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-39-49
# 1
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.43it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-39-55
# 2
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.50it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-40-02
# 3
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.48it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-40-09
# 4
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.37it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-40-16
# 5
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.46it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-40-22
# 6
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.48it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-40-29
# 7
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.17it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-40-36
# 8
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.40it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-40-43
# 9
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.35it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-40-49
# 10
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.28it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-40-56
# 11
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.47it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-41-03
# 12
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.19it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-41-10
# 13
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.32it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-41-16
# 14
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.50it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-41-23
# 15
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.31it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-41-30
# 16
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.34it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-41-37
# 17
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.47it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-41-43
# 18
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.17it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-41-50
# 19
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.33it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-41-57
# 20
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.32it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-42-03
# 21
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.61it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-42-10
# 22
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.24it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-42-17
# 23
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.29it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-42-23
# 24
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.59it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-42-30
# 25
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.38it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-42-37
# 26
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.46it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-42-44
# 27
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.29it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-42-50
# 28
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.07it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-42-57
# 29
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.43it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-43-04
# 30
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.46it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-43-11
# 31
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.43it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-43-17
# 32
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.25it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-43-24
# 33
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.46it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-43-31
# 34
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.19it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-43-38
# 35
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.34it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-43-44
# 36
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.41it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-43-51
# 37
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.42it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-43-58
# 38
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.36it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-44-05
# 39
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  2.42it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-44-11
# 40
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.35it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-44-18
# 41
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.48it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-44-25
# 42
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.48it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-44-32
# 43
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.47it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-44-38
# 44
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.16it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09-44-45
# 45
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.34it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_09
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.41it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-10-01
# 270
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.28it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-10-08
# 271
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.35it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-10-14
# 272
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.25it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-10-21
# 273
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.49it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-10-28
# 274
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.38it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-10-35
# 275
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.36it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-10-42
# 276
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.41it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-10-48
# 277
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.39it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-10-55
# 278
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.02it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-11-01
# 279
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.17it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-11-08
# 280
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.39it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-11-15
# 281
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.32it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-11-21
# 282
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.50it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-11-28
# 283
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  2.28it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-11-35
# 284
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.36it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-11-42
# 285
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.35it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-11-48
# 286
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.47it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-11-55
# 287
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.40it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-12-02
# 288
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  2.32it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-12-09
# 289
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.41it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-12-15
# 290
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.30it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-12-22
# 291
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.45it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-12-29
# 292
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.28it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-12-36
# 293
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.28it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-12-43
# 294
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.44it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-12-49
# 295
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.41it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-12-56
# 296
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.38it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-13-03
# 297
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.42it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-13-10
# 298
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.22it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-13-16
# 299
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.37it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-13-23
# 300
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.41it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-13-30
# 301
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.38it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-13-36
# 302
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.42it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-13-43
# 303
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.52it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-13-50
# 304
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.27it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-13-56
# 305
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.33it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-14-03
# 306
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.20it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-14-10
# 307
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.27it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-14-16
# 308
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.31it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-14-23
# 309
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.34it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-14-30
# 310
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.45it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-14-37
# 311
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.34it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-14-43
# 312
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.24it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-14-50
# 313
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.22it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-14-57
# 314
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.38it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-15-04
# 315
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.29it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-15-10
# 316
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.35it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-15-17
# 317
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.30it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-15-24
# 318
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.17it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-15-31
# 319
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.27it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-15-38
# 320
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.49it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-15-44
# 321
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.33it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-15-51
# 322
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.53it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-15-58
# 323
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.18it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-16-04
# 324
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.32it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-16-11
# 325
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.44it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-16-18
# 326
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.26it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-16-25
# 327
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.33it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-16-31
# 328
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.25it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-16-38
# 329
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.33it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-16-44
# 330
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.39it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-16-51
# 331
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.38it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-16-58
# 332
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.33it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-17-05
# 333
# continuing from previous epoch - 150
# loading from version 1.8.1
# 100% 1/1 [00:00<00:00,  3.21it/s]
# sample images generated at ./gdrive/MyDrive/HW6/output/faces/generated-05-01-2021_10-17-11

# %% [markdown]
# # submit form

# %% [markdown]
# check the number of images

# %%
ls ./gdrive/MyDrive/HW6/output/faces | wc -l
# Out:
# 1000

# %% [markdown]
# randomly delete 2 extra images

# %%
from random import sample
import os

files = os.listdir("./gdrive/MyDrive/HW6/output/faces")
for file in sample(files,2):
    os.remove("./gdrive/MyDrive/HW6/output/faces/"+file)

# %% [markdown]
# change file name as 1 2 3 ...

# %%
import os
  
os.chdir("./gdrive/MyDrive/HW6/output/faces")
print(os.getcwd())
COUNT = 1
  
# Function to increment count 
# to make the files sorted.
def increment():
    global COUNT
    COUNT = COUNT + 1
  
  
for f in os.listdir():
    f_name, f_ext = os.path.splitext(f)
    f_name =  str(COUNT)
    increment()
  
    new_name = '{} {}'.format(f_name, f_ext)
    os.rename(f, new_name)
# Out:
# /content/gdrive/MyDrive/HW6/output/faces

# %% [markdown]
# compress data

# %%
# Compress the images.
# %cd {workspace_dir}/output/faces
# !tar -zcf ../images.tgz *.jpg
# %cd ..
# Out:
# [Errno 2] No such file or directory: './gdrive/MyDrive/HW6/output/faces'
# /content
# /content/gdrive/My Drive/HW6/output
